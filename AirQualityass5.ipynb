# %%
import pandas as pd
import numpy as np
data= pd.read_csv("/content/city_day.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of                 City        Date  PM2.5  ...  Xylene   AQI    AQI_Bucket
# 0          Ahmedabad  2015-01-01    NaN  ...    0.00   NaN           NaN
# 1          Ahmedabad  2015-01-02    NaN  ...    3.77   NaN           NaN
# 2          Ahmedabad  2015-01-03    NaN  ...    2.25   NaN           NaN
# 3          Ahmedabad  2015-01-04    NaN  ...    1.00   NaN           NaN
# 4          Ahmedabad  2015-01-05    NaN  ...    2.78   NaN           NaN
# ...              ...         ...    ...  ...     ...   ...           ...
# 29526  Visakhapatnam  2020-06-27  15.02  ...    0.73  41.0          Good
# 29527  Visakhapatnam  2020-06-28  24.38  ...    0.38  70.0  Satisfactory
# 29528  Visakhapatnam  2020-06-29  22.91  ...    0.00  68.0  Satisfactory
# 29529  Visakhapatnam  2020-06-30  16.64  ...    0.00  54.0  Satisfactory
# 29530  Visakhapatnam  2020-07-01  15.00  ...     NaN  50.0          Good
#
# [29531 rows x 16 columns]>

# %%
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
data.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
data.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# Here we obsersve that we have null values in 14 columns.

# %%
fully_null_rows = data.drop(columns=data.columns[[0, 1]]).isnull().all(axis=1)

# Filter the original DataFrame to get the rows that are fully null in the selected columns
fully_null_rows_data = data[fully_null_rows]

# Display the result
if fully_null_rows_data.empty:
    print("There are no rows that are fully null in the specified columns.")
else:
    print("Rows that are fully null in the specified columns:")
    print(fully_null_rows_data)
# Out:
# Rows that are fully null in the specified columns:
#                 City        Date  PM2.5  PM10  NO  NO2  NOx  NH3  CO  SO2  O3  \
# 56         Ahmedabad  2015-02-26    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 57         Ahmedabad  2015-02-27    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 58         Ahmedabad  2015-02-28    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 64         Ahmedabad  2015-03-06    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 262        Ahmedabad  2015-09-20    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# ...              ...         ...    ...   ...  ..  ...  ...  ...  ..  ...  ..
# 29226  Visakhapatnam  2019-09-01    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 29227  Visakhapatnam  2019-09-02    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 29228  Visakhapatnam  2019-09-03    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# 29229  Visakhapatnam  2019-09-04    NaN   NaN NaN  NaN  NaN  NaN NaN  NaN NaN
# ...

# %%
fully_null_rows_data.shape
# Out:
# (1374, 16)

# %% [markdown]
# Here we observe that there is no data entered for 1374 days. since no data is present here we deelte these rows.

# %%
data.dropna(subset=['AQI', 'AQI_Bucket'], inplace=True)

# %%
data.isna().sum()
# Out:
# City              0
# Date              0
# PM2.5           678
# PM10           7086
# NO              387
# NO2             391
# NOx            1857
# NH3            6536
# CO              445
# SO2             605
# O3              807
# Benzene        3535
# Toluene        5826
# Xylene        15372
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
# Visualizing Missing Data using a seaborn heatmap.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))

sns.heatmap(data.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %%
df=data.iloc[:, 2:-2]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(1,3,1)
sns.distplot(df["PM10"])
plt.title("NO2")

plt.subplot(1,3,2)
sns.distplot(df["NO2"])
plt.title("SO2")

plt.subplot(1,3,3)
sns.distplot(df["PM2.5"])
plt.title("cO")



plt.show()
# Out:
# <ipython-input-15-8f2f1357c397>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["PM10"])
# <ipython-input-15-8f2f1357c397>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["NO2"])
# <ipython-input-15-8f2f1357c397>:13: UserWarning:
#
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
data.iloc[:, 2:-2] = imputer.fit_transform(data.iloc[:, 2:-2])

# %%
data.isna().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %% [markdown]
# Check to confirm if the process id done sucessfully.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns to plot
columns_to_plot = ['NO2', 'SO2', 'CO', 'O3', 'PM10', 'PM2.5', 'AQI', 'NO', 'Xylene', 'Toluene', 'Benzene', 'NH3', 'NOx']

# Set the number of rows and columns for the subplots
n_rows = 4
n_cols = 4

# Create a figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 15))
axes = axes.flatten()  # Flatten the 2D array of axes for easy iteration

# Loop through the columns and create a boxplot for each
for i, column in enumerate(columns_to_plot):
    sns.boxplot(data[column], ax=axes[i])
    axes[i].set_title(column)

# Hide any unused subplots
for j in range(len(columns_to_plot), n_rows * n_cols):
    fig.delaxes(axes[j])

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# We observe that there are a lot of outliers in each boxplot

# %% [markdown]
# Understanding Outliers
# Identify Outliers: You've already visualized the data with boxplots, which is a good start. Consider also calculating the IQR (Interquartile Range) to define outliers more formally.
# IQR Method: An observation is considered an outlier if it is below
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# Q1−1.5×IQR or above
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# Q3+1.5×IQR, where
# 𝑄
# 1
# Q1 and
# 𝑄
# 3
# Q3 are the first and third quartiles, respectively.

# %%
# Define a function to filter out outliers using the IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] >= Q1 - 1.5 * IQR) & (df[column] <= Q3 + 1.5 * IQR)]

# Apply the function to the relevant columns
for col in columns_to_plot:
    data = remove_outliers_iqr(data, col)

# %%
for col in columns_to_plot:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data[col] = np.where(data[col] < lower_bound, lower_bound, data[col])
    data[col] = np.where(data[col] > upper_bound, upper_bound, data[col])

# %% [markdown]
# #  Transforming Data
# You might apply transformations to reduce the impact of outliers, such as:
#
# Log Transformation: Useful for positively skewed data.

# %%
data['PM10'] = np.log1p(data['PM10'])  # Applying log transformation

# %%
plt.figure(figsize=(20, 15))
for i, column in enumerate(columns_to_plot):
    plt.subplot(4, 4, i + 1)
    sns.boxplot(data[column])
    plt.title(column)
plt.tight_layout()
plt.show()
